# %% [markdown]
# <a href="https://colab.research.google.com/github/edisonc57/exercises/blob/main/Mattar's_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
  a1 = 0.3265;
  a2 = -1.0700;
  a3 = -0.5339;
  a4 = 0.01569;
  a5 = -0.05165;
  a6 = 0.5475;
  a7 = -0.7361;
  a8 = 0.1844;
  a9 = 0.1056;
  a10 = 0.6134;
  a11 = 0.7210;
  опг= 0.74469116
  z = 0.7730733
  T_pr = 1.5005661019949397
  P_pr = 3.1995450990234966
  пг= 0.7
  P_pc= 756.8 - 131.07*пг -3.6*пг**2
  T_pc= 169.2 + 349.5*пг - 74*пг**2

  dz= ((a1 + (a2/T_pr) + (a3/T_pr**3) +(a4/T_pr**4) + (a5/T_pr**5)) * опг) + \
      (2 * ((a6 + (a7/T_pr) + (a8/T_pr**2))) * опг**2) - \
      (5 * a9 * (((a7/T_pr) + (a8/T_pr**2))) * опг**4) + (1 + (a11 * опг**2) - (a11 * опг**2)**2) \
      * ((2 * a10 * опг/ T_pr**3)*np.exp(-a11 * опг**2))

  Cgas= (1 / (P_pr * P_pc)) - ((0.27 / (z**2 * ( T_pr * P_pc))) * (dz / (1 + ((опг / z) * dz))))

  print ("isothermal compressibility of Gas ", Cgas, "psi ^ -1")
# Out:
# isothermal compressibility of Gas  0.00045505800685975044 psi ^ -1
