# %% [markdown]
# <a href="https://colab.research.google.com/github/edisonc57/exercises/blob/main/Raschet_otnositel'noy_pronitsayemosti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Расчет относительной проницаемости  Steady-State test

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !pip install --upgrade matplotlib

# %%
поток= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/FlowRate.csv")

# %%
поток
# Out:
#      Sw      qo     qw
# 0  0.00  0.0600  0.000
# 1  0.20  0.0420  0.000
# 2  0.30  0.0300  0.010
# 3  0.40  0.0200  0.020
# 4  0.50  0.0130  0.035
# 5  0.60  0.0075  0.051
# 6  0.70  0.0040  0.068
# 7  0.80  0.0010  0.085
# 8  0.85  0.0000  0.096
# 9  1.00  0.0000  0.250

# %%
Qo = plt.plot(поток.Sw,поток.qo)
Qw= plt.plot(поток.Sw, поток.qw)
plt.xlabel("Sw"), plt.ylabel("Qo, Qw")
plt.title("Flow rates")
plt.legend((Qo[0], Qw[0]), ('q_oil', 'q_water'))

# %%
#fig, p1 = plt.subplots()
#p1.plot(flowrate['Sw'], flowrate['qo'], marker='o', linestyle='-', color='b', label='')
#p1.set_xlabel('Sw')
#p1.set_ylabel('qo')


#p2 = p1.twinx()
#p2.plot(flowrate['Sw'], flowrate['qw'], marker='x', linestyle='-', color='r', label=' ')
#p2.set_ylabel('qw')
#p1.set_ylim(p2.get_ylim())

#plt.title('Flow rate')

# %%
Kr_o=поток.qo / поток.qo[0]
Kr_w= поток.qw/ поток.qw[9]
#print(Kro)
#print(Krw)

Kro=plt.plot(поток.Sw, Kr_o)
Krw= plt.plot(поток.Sw, Kr_w)
plt.legend((Kro[0], Krw[0]), ('kro', 'krw'))

# %%
Вязкость_нефти= 0.5
Вязкость_вода= 1.2
площадь_сечения = 5
длина_образца  = 12
перепад_давления = -2.5

Ko=-(поток.qo*Вязкость_нефти/площадь_сечения )*(перепад_давления/длина_образца)
Kw= -(поток.qw*Вязкость_вода/площадь_сечения )*(перепад_давления/длина_образца)
print( Ko)
print (Kw)
# Out:
# 0    0.001250
# 1    0.000875
# 2    0.000625
# 3    0.000417
# 4    0.000271
# 5    0.000156
# 6    0.000083
# 7    0.000021
# 8    0.000000
# 9    0.000000
# Name: qo, dtype: float64
# 0    0.00000
# 1    0.00000
# 2    0.00050
# 3    0.00100
# 4    0.00175
# 5    0.00255
# 6    0.00340
# 7    0.00425
# 8    0.00480
# 9    0.01250
# Name: qw, dtype: float64
