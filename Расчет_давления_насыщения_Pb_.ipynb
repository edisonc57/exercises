# %% [markdown]
# <a href="https://colab.research.google.com/github/edisonc57/exercises/blob/main/%D0%A0%D0%B0%D1%81%D1%87%D0%B5%D1%82_%D0%B4%D0%B0%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F_%D0%BD%D0%B0%D1%81%D1%8B%D1%89%D0%B5%D0%BD%D0%B8%D1%8F_Pb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Rsb= 500
Tr= 220
Sg= 0.8
API= 30

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Sgs=(0.00091*Tr)-(0.0125*API)
PbS= 18*(10**Sgs)*((Rsb/Sg)**0.83)

# %%
print("Давление насыщение с помощью корреляции Standing", PbS, "psi")
# Out:
# Давление насыщение с помощью корреляции Standing 2517.983729536601 psi

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
if API<=30:
  c1=0.0362
  c2=1.0937
  c3=25.7240

if API>=30:
  c1=0.0178
  c2=1.187
  c3= 23.9310

PbV= ((Rsb)/(c1*Sg*np.exp((c3*API)/(Tr+459.67))))**(1/c2)

# %%
print("Давление насыщение с помощью корреляции Vasquez and Beggs", PbV, "psi")
# Out:
# Давление насыщение с помощью корреляции Vasquez and Beggs 2772.6596408726605 psi
